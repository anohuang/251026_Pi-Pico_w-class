# %%
print ("Hello! Python")
# Out:
# Hello! Python

# %%
a = 10
b=3
print(a+b) #10+3
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
print(a==b)
print(a!=b)
print(a>=b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000
# False
# True
# True
